# %%
import cv2
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/salma/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:01<00:00, 3.32MB/s]

# %%
result = model.train(data = "data.yaml",epochs = 10)
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 5930MiB)
# ...

# %%
result_plts = cv2.imread('runs/detect/train4/results.png')
result_plts= cv2.cvtColor(result_plts, cv2.COLOR_BGR2RGB)
plt.Figure(figsize=(1000,1000))
plt.imshow(result_plts)

# %%
pred = model("Traffic-signals.png",save =True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pred = model("Traffic-signals.png",save =True)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)
#     180         ...     print(f"Detected {len(r)} objects in image")
#     181     """
# --> 182     return self.predict(source, stream, **kwargs)
#
# ...

# %%
print(pred)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'biker', 1: 'car', 2: 'pedestrian', 3: 'trafficLight', 4: 'trafficLight-Green', 5: 'trafficLight-GreenLeft', 6: 'trafficLight-Red', 7: 'trafficLight-RedLeft', 8: 'trafficLight-Yellow', 9: 'trafficLight-YellowLeft', 10: 'truck'}
# obb: None
# orig_img: array([[[225, 179, 132],
#         [224, 178, 131],
#         [222, 179, 132],
#         ...,
#         [151, 116, 102],
#         [156, 131, 111],
#         [137, 115,  99]],
#
#        [[225, 179, 132],
#         [224, 178, 131],
#         [222, 178, 131],
#         ...,
#         [140, 112,  93],
#         [134, 111,  89],
#         [130, 105,  87]],
#
#        [[223, 178, 131],
#         [223, 178, 131],
#         [223, 179, 132],
#         ...,
#         [118, 100,  81],
#         [121, 101,  85],
#         [138, 110, 101]],
#
#        ...,
#
#        [[118, 116, 116],
# ...

# %%
import cv2 
import matplotlib.pyplot as plt

img = cv2.imread("runs/detect/train46/street-signals.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
model.save("yolov8n_road.pt")

# %%
loaded_model = YOLO("yolov8n_road.pt")

# %%
image = cv2.imread("Traffic-signals.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (640, 640))  # Resize (but loses aspect ratio)
image = image / 255.0  # Normalize

# Convert to tensor and fix channel order
image = torch.from_numpy(image).to(loaded_model.device).float()
image = image.permute(2, 0, 1)  # Change from HWC to CHW
image = image.unsqueeze(0)  # Add batch dimension

# Now pass to model
with torch.no_grad():
    raw_tensor = loaded_model.model(image)

# %%
# Access the tensor inside the tuple
tensor = raw_tensor[0]
print(tensor.shape)
# Out:
# torch.Size([1, 15, 8400])

# %%
image = cv2.imread("Traffic-signals.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (640, 640))  # Resize (but loses aspect ratio)
image = image / 255.0  # Normalize

print(image)
import matplotlib.pyplot as plt
plt.imshow(image)
preds = loaded_model.predict(image)

for pred in preds :
    boxes = pred.boxes.xyxy
    conf = pred.boxes.conf
    class_id = pred.boxes.cls

print("Boxes:", boxes)
print("Conf:",conf)
print("Class IDs:",class_id)
# Out:
# [[[132 179 225]
#   [131 178 224]
#   [131 178 223]
#   ...
#   [106 123 153]
#   [107 126 150]
#   [ 99 115 137]]
#
#  [[132 179 225]
#   [131 178 224]
#   [131 178 223]
#   ...
#   [103 121 150]
#   [103 123 147]
#   [ 96 113 136]]
#
#  [[132 179 225]
#   [131 178 224]
#   [131 178 223]
#   ...
#   [ 96 115 142]
#   [ 95 115 138]
#   [ 91 108 132]]
#
#  ...
#
#  [[117 118 120]
#   [117 118 120]
#   [118 119 121]
#   ...
#   [102 103 108]
#   [101 102 107]
#   [101 103 108]]
#
#  [[117 118 120]
#   [118 119 121]
#   [118 119 121]
#   ...
#   [102 103 108]
#   [102 103 108]
#   [103 103 108]]
#
#  [[117 118 120]
#   [118 119 121]
#   [118 119 121]
#   ...
#   [102 103 108]
#   [102 103 108]
#   [103 104 108]]]
#
# 0: 640x640 11 cars, 1 trafficLight-Green, 1 trafficLight-Red, 1 trafficLight-Yellow, 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Boxes: tensor([[ 87.2570, 415.8334, 156.2248, 510.8105],
# ...

# %%
from object_detectors_attacks import targeted_dag_attack as tdag

# %%
image = cv2.imread('Traffic-signals.png')  # BGR image

adversarial_images, _ = tdag(
    model=loaded_model,
    images=[image], 
    target_objects=[3],  # Example: stop sign class
    adversarial_classes=[1],  # Example: car class
    max_iter=20,
    gamma=0.1,
    device='cuda'
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 3
#       1 image = cv2.imread('Traffic-signals.png')  # BGR image
# ----> 3 adversarial_images, _ = tdag(
#       4     model=loaded_model,
#       5     images=[image],
#       6     target_objects=[3],  # Example: stop sign class
#       7     adversarial_classes=[1],  # Example: car class
#       8     max_iter=20,
#       9     gamma=0.1,
#      10     device='cuda'
#      11 )
#
# File ~/Uni/GP/org/YOLOv8/object_detectors_attacks.py:57, in targeted_dag_attack(model, images, target_objects, adversarial_classes, max_iter, gamma, output_dir, im_name_prefix, device)
#      55 # Forward pass through YOLOv8
#      56 with torch.no_grad():
# ---> 57     raw_output = model.model(adv_batch)
#      58     results = model.predictor.postprocess(raw_output, adv_batch, original_images)
#      60 # Get current detections
# ...

# %%
import cv2
import numpy as np

def letterbox(img, new_shape=(640, 640), color=(114, 114, 114), auto=True, scaleFill=False, scaleup=True, stride=32):
    """
    Resize and pad image while meeting stride-multiple constraints.

    Parameters:
        img (np.array): Input image.
        new_shape (tuple): Desired output shape as (height, width).
        color (tuple): Border color for padding.
        auto (bool): If True, make the padding a multiple of stride.
        scaleFill (bool): If True, stretch the image to fill new_shape (may distort aspect ratio).
        scaleup (bool): If False, only downscale the image.
        stride (int): Stride for ensuring padded dimensions are multiples.

    Returns:
        img (np.array): The resized and padded image.
        ratio (float): Scaling ratio used.
        (dw, dh) (tuple): Padding added (width, height) on each side.
    """
    # Current shape [height, width]
    shape = img.shape[:2]
    if isinstance(new_shape, int):
        new_shape = (new_shape, new_shape)

    # Calculate scale ratio (new / old) and ensure it doesn't upscale if scaleup is False.
    r = min(new_shape[0] / shape[0], new_shape[1] / shape[1])
    if not scaleup:
        r = min(r, 1.0)

    # Compute new unpadded dimensions
    new_unpad = (int(round(shape[1] * r)), int(round(shape[0] * r)))
    # Compute padding
    dw = new_shape[1] - new_unpad[0]
    dh = new_shape[0] - new_unpad[1]

    if auto:
        # Make sure padding is a multiple of stride
        dw, dh = np.mod(dw, stride), np.mod(dh, stride)
    elif scaleFill:
        # Stretch image to fill new_shape, disregarding aspect ratio
        dw, dh = 0, 0
        new_unpad = (new_shape[1], new_shape[0])
        r = new_shape[1] / shape[1], new_shape[0] / shape[0]

    # Divide padding into 2 sides
    dw /= 2  # width padding (left/right)
    dh /= 2  # height padding (top/bottom)

    # Resize image if necessary
    if shape[::-1] != new_unpad:
        img = cv2.resize(img, new_unpad, interpolation=cv2.INTER_LINEAR)

    # Compute padding values for top, bottom, left, right
    top = int(round(dh - 0.1))
    bottom = int(round(dh + 0.1))
    left = int(round(dw - 0.1))
    right = int(round(dw + 0.1))

    # Apply padding
    img = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    
    return img, r, (dw, dh)

# Example usage:
if __name__ == "__main__":
    # Load an image using OpenCV
    img = cv2.imread("Traffic-signals.png")
    # Convert BGR to RGB if needed
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Apply letterbox
    resized_img, ratio, padding = letterbox(img, new_shape=(640, 640))
    
    # Show the result (convert back to BGR for OpenCV display if needed)
    plt.imshow(resized_img/255)

# %%
import torch
# Load the image using OpenCV
img_bgr = cv2.imread('Traffic-signals.png')

# Step 1: Convert BGR to RGB
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Step 2: Letterbox resize to desired dimensions (e.g., 640x640)
img_resized, ratio, pad = letterbox(img_rgb, new_shape=(640, 640), auto=True)

# Step 3: Convert image to float and normalize pixel values to [0, 1]
img_normalized = img_resized.astype(np.float32) / 255.0

# Step 4: Change data layout from HWC to CHW
img_transposed = np.transpose(img_normalized, (2, 0, 1))

# Step 5: Add batch dimension
img_batch = np.expand_dims(img_transposed, 0)

# Step 6: Convert to PyTorch tensor
img_tensor = torch.from_numpy(img_batch)

loaded_model.predict(img_tensor)

# %%
loaded_model.predict('Traffic-signals.png')
# Out:
# image 1/1 /home/youssef-abuzeid/Uni/GP/org/YOLOv8/Traffic-signals.png: 384x640 17 cars, 1 pedestrian, 6 trafficLight-Greens, 1 trafficLight-RedLeft, 1 truck, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'biker', 1: 'car', 2: 'pedestrian', 3: 'trafficLight', 4: 'trafficLight-Green', 5: 'trafficLight-GreenLeft', 6: 'trafficLight-Red', 7: 'trafficLight-RedLeft', 8: 'trafficLight-Yellow', 9: 'trafficLight-YellowLeft', 10: 'truck'}
#  obb: None
#  orig_img: array([[[225, 179, 132],
#          [224, 178, 131],
#          [222, 179, 132],
#          ...,
#          [151, 116, 102],
#          [156, 131, 111],
#          [137, 115,  99]],
#
#         [[225, 179, 132],
#          [224, 178, 131],
#          [222, 178, 131],
#          ...,
#          [140, 112,  93],
# ...
