# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
result = model.train(data = "data.yaml",epochs = 10)
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 5930MiB)
# ...

# %%
result_plts = cv2.imread('runs/detect/train4/results.png')
result_plts= cv2.cvtColor(result_plts, cv2.COLOR_BGR2RGB)
plt.Figure(figsize=(1000,1000))
plt.imshow(result_plts)

# %%
pred = model("Traffic-signals.png",save =True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pred = model("Traffic-signals.png",save =True)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)
#     180         ...     print(f"Detected {len(r)} objects in image")
#     181     """
# --> 182     return self.predict(source, stream, **kwargs)
#
# ...

# %%
print(pred)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'biker', 1: 'car', 2: 'pedestrian', 3: 'trafficLight', 4: 'trafficLight-Green', 5: 'trafficLight-GreenLeft', 6: 'trafficLight-Red', 7: 'trafficLight-RedLeft', 8: 'trafficLight-Yellow', 9: 'trafficLight-YellowLeft', 10: 'truck'}
# obb: None
# orig_img: array([[[225, 179, 132],
#         [224, 178, 131],
#         [222, 179, 132],
#         ...,
#         [151, 116, 102],
#         [156, 131, 111],
#         [137, 115,  99]],
#
#        [[225, 179, 132],
#         [224, 178, 131],
#         [222, 178, 131],
#         ...,
#         [140, 112,  93],
#         [134, 111,  89],
#         [130, 105,  87]],
#
#        [[223, 178, 131],
#         [223, 178, 131],
#         [223, 179, 132],
#         ...,
#         [118, 100,  81],
#         [121, 101,  85],
#         [138, 110, 101]],
#
#        ...,
#
#        [[118, 116, 116],
# ...

# %%
import cv2 
import matplotlib.pyplot as plt

img = cv2.imread("runs/detect/train46/street-signals.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
model.save("yolov8n_road.pt")

# %%
loaded_model = YOLO("yolov8n_road.pt")

# %%
import torch
# Load and preprocess image
image = cv2.imread("Traffic-signals.png")

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
image = cv2.resize(image, (640, 640))
image = image/255
# Convert to tensor and add batch dimension
image = torch.from_numpy(image).to(loaded_model.device)
image = torch._cast_Float(image)
image = image.unsqueeze(0)  # Shape: [1, 3, 640, 640]

# Run model inference (raw tensor output)
with torch.no_grad():
    raw_tensor = loaded_model.model(image)  # Access the underlying PyTorch model

# raw_tensor is a list of tensors (e.g., for detection: [1, 84, 8400])
print(raw_tensor[0].shape)  # Example output: torch.Size([1, 84, 8400])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 15
#      13 # Run model inference (raw tensor output)
#      14 with torch.no_grad():
# ---> 15     raw_tensor = loaded_model.model(image)  # Access the underlying PyTorch model
#      17 # raw_tensor is a list of tensors (e.g., for detection: [1, 84, 8400])
#      18 print(raw_tensor[0].shape)  # Example output: torch.Size([1, 84, 8400])
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
# ...

# %%
print(pred)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'biker', 1: 'car', 2: 'pedestrian', 3: 'trafficLight', 4: 'trafficLight-Green', 5: 'trafficLight-GreenLeft', 6: 'trafficLight-Red', 7: 'trafficLight-RedLeft', 8: 'trafficLight-Yellow', 9: 'trafficLight-YellowLeft', 10: 'truck'}
# obb: None
# orig_img: array([[[225, 179, 132],
#         [224, 178, 131],
#         [222, 179, 132],
#         ...,
#         [151, 116, 102],
#         [156, 131, 111],
#         [137, 115,  99]],
#
#        [[225, 179, 132],
#         [224, 178, 131],
#         [222, 178, 131],
#         ...,
#         [140, 112,  93],
#         [134, 111,  89],
#         [130, 105,  87]],
#
#        [[223, 178, 131],
#         [223, 178, 131],
#         [223, 179, 132],
#         ...,
#         [118, 100,  81],
#         [121, 101,  85],
#         [138, 110, 101]],
#
#        ...,
#
#        [[118, 116, 116],
# ...
